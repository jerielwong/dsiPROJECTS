# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# ## Executive Summary
#
# SAT is a globally renown examination that allows students globally to take, which is critical for university admissions.
#
# Universities adopt the SAT score as part of their admission criteria, this provides a standardize scoring system for students to be evaluated for the schools they wish to enter.
#
# However, there is also another examination which is known as ACT, where univerities have also accepted as an admission test.
#
# College Board which administers SAT, seeks to gain back market share in this global examination, or seek improvements to their scoring system

# %% [markdown]
# ## Problem Statement
#
# The College Board administers multiple examinations and tests for students across United States of America. One of their most reputable examination test is the SAT examination, where students take the SAT test so as to enter universities in the USA, as their admission criteria.
#
# There is also another test known as the ACT which is the competitior of SAT, that students cna now take for their universiity admission.
#
# College board seeks to drive participation rate higher, by studying the factors why certain states in USA has such high participation rate for the ACT examination.

# %% [markdown]
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)
# - [123](#JERIEL)

# %% [markdown]
# Data Dictionary
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|SAT|State where students took the exam|
# |sat_parti_2017|float|SAT|Participation rate of each state in 2017 for SAT|
# |sat_erw_2017|float|SAT|Evidence-Based Reading and Writing score of each state in 2017 for SAT, between 200 and 800|
# |sat_math_2017|float|SAT|Math score of each state in 2017 for SAT, between 200 and 800|
# |act_parti_2017|float|ACT|Participation rate of each state in 2017 for ACT|
# |act_english_2017|float|ACT|English score of each state in 2017 for ACT, between 1 and 36|
# |act_math_2017|float|ACT|Math score of each state in 2017 for ACT, between 1 and 36|
# |act_reading_2017|float|ACT|Reading score of each state in 2017 for ACT, between 1 and 36|
# |act_science_2017|float|ACT|Science score of each state in 2017 for ACT, between 1 and 36|
# |act_composite_2017|float|ACT|Composite score of each state in 2017 for ACT, averaging scores from four sections, between 1 and 36|

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:

import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib as plt 
import matplotlib.pyplot as plt


# %matplotlib inline

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code:
satdata2017 = pd.read_csv('../data/sat_2017.csv')
actdata2017 = pd.read_csv('../data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code:
satdata2017.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
actdata2017.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer
#
# SAT 2017 data
#
# - 50 entries, with 5 columns in the order of State Participation Evidence-Based Reading and Writing Math Total
#
# - Each state, participation percentage, scores of Evidence-Based Reading and Writing, Math and Total
#
# - Total, without any validation yet, seems to be the sum of Evidence-Based Reading and Writing + Math
#
# - Column values are integers
#
# ACT 2017 data
#
# - 51 entries, with 7 columns in order of State Participation English Math Reading Science Composite
#
# - Column values are float, as there is decimal places
#
# - an additional row at the top National, which is not a state

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# #### Answer:
#
# Through checking of columns of SAT 2017 and ACT 2017 for null values, there is no missing values, besides SAT is missing the National row

# %%
actdata2017.isnull().sum()
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64

# %%
satdata2017.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# #### Answer:
#
# ACT 2017
#
#
# - the maximum scored for ACT test 2017 for the following subjects
# english = 25.5
# math  = 25.3
# reading = 26
# science = 24.9
#
# - 1 or more of the states has a very low minimum score for science
#
# SAT 2017
#
#
# - the maximum possible value for SAT test 2017 for the follwoing subjects
# ERT = 644
# Math = 651
# Total = 1295
#
# - 1 or more of the states score a min of 52 for Math, which is drastically off the mean of 547

# %%
satdata2017.describe().T
# Out:
#                                     count         mean        std    min  \
# Evidence-Based Reading and Writing   51.0   569.117647  45.666901  482.0
# Math                                 51.0   547.627451  84.909119   52.0
# Total                                51.0  1126.098039  92.494812  950.0
#
#                                        25%     50%     75%     max
# Evidence-Based Reading and Writing   533.5   559.0   613.0   644.0
# Math                                 522.0   548.0   599.0   651.0
# Total                               1055.5  1107.0  1212.0  1295.0

# %%
actdata2017.describe().T
# Out:
#          count       mean       std   min     25%    50%     75%   max
# English   52.0  20.919231  2.332132  16.3  19.000  20.55  23.300  25.5
# Math      52.0  21.173077  1.963602  18.0  19.400  20.90  23.100  25.3
# Reading   52.0  22.001923  2.048672  18.1  20.475  21.70  24.125  26.0
# Science   52.0  21.040385  3.151113   2.3  19.900  21.15  22.525  24.9

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %% [markdown]
# SAT 2017
#
# - FIX 1 = Maryland Math to 524
#
#
# ACT 2017
#
# - FIX 2 =  Wyoming Composite to 20.2
# - FIX 3 = Maryland Science = 23.2

# %%
#code

# FIX 1 : SAT 2017 data maryland Math
satdata2017.loc[satdata2017['State'] =='Maryland',['Math']] = 524
print(satdata2017.loc[satdata2017['State'] =='Maryland',['Math']])

# FIX 2 :  ACT 2017 data Wyoming Composite
actdata2017.loc[actdata2017['State'] =='Wyoming',['Composite']] = 20.2
print(actdata2017.loc[actdata2017['State'] =='Wyoming',['Composite']] )

# FIX 3 : ACT SCIENCE 2017 Marland Math
actdata2017.loc[actdata2017['State'] =='Maryland',['Science']] = 23.2
print(actdata2017.loc[actdata2017['State'] =='Maryland',['Science']])
# Out:
#     Math
# 20   524
#    Composite
# 51      20.2
#     Science
# 21     23.2

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#code
satdata2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
actdata2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer
#
# SAT 2017
#
# - Participation should be remove % and be converted to a float, for calculation purposes
#
#
# ACT 2017
#
# - Participation should be remove % and be converted to a float, for calculation purposes
# - Composite column should be float as it is a score.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
#code
def partici_to_number(partici):
    if '%'  not in str(partici):
        partici = float(partici)
    else:
        partici = partici.replace('%','')
        partici = float(partici)
    return partici

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
###  ACT 2017  Participation removing % , and convert to float
actdata2017['Participation'] = actdata2017['Participation'].map(partici_to_number)

# %%
###  SAT 2017 Participation removing % , and convert to float
satdata2017['Participation'] = satdata2017['Participation'].map(partici_to_number)

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
## SAT all columns to float

for columns in satdata2017.columns[2:]:
    if satdata2017[columns].dtypes != 'float':
        satdata2017[columns] = satdata2017[columns].astype('float')

# %%
## ACT all columns to float

for columns in actdata2017.columns[2:]:
    if actdata2017[columns].dtypes != 'float':
        actdata2017[columns] = actdata2017[columns].astype('float')

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
actdata2017.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %%
satdata2017.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing    float64
# Math                                  float64
# Total                                 float64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
def update_cols(df,prefix):
    df.columns = [x.lower().replace('evidence-based reading and writing','ebrw') for x in df.columns]
    df.columns = [prefix + x if x !='state' else x for x in df.columns]
    return df

# %%
update_cols(actdata2017, 'act2017_')
update_cols(satdata2017, 'sat2017_')
# Out:
#                    state  sat2017_participation  sat2017_ebrw  sat2017_math  \
# 0                Alabama                    5.0         593.0         572.0
# 1                 Alaska                   38.0         547.0         533.0
# 2                Arizona                   30.0         563.0         553.0
# 3               Arkansas                    3.0         614.0         594.0
# 4             California                   53.0         531.0         524.0
# 5               Colorado                   11.0         606.0         595.0
# 6            Connecticut                  100.0         530.0         512.0
# 7               Delaware                  100.0         503.0         492.0
# 8   District of Columbia                  100.0         482.0         468.0
# 9                Florida                   83.0         520.0         497.0
# 10               Georgia                   61.0         535.0         515.0
# ...

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|SAT|State where students took the exam|
# |sat_parti_2017|float|SAT|Participation rate of each state in 2017 for SAT|
# |sat_erw_2017|float|SAT|Evidence-Based Reading and Writing score of each state in 2017 for SAT, between 200 and 800|
# |sat_math_2017|float|SAT|Math score of each state in 2017 for SAT, between 200 and 800|
# |act_parti_2017|float|ACT|Participation rate of each state in 2017 for ACT|
# |act_english_2017|float|ACT|English score of each state in 2017 for ACT, between 1 and 36|
# |act_math_2017|float|ACT|Math score of each state in 2017 for ACT, between 1 and 36|
# |act_reading_2017|float|ACT|Reading score of each state in 2017 for ACT, between 1 and 36|
# |act_science_2017|float|ACT|Science score of each state in 2017 for ACT, between 1 and 36|
# |act_composite_2017|float|ACT|Composite score of each state in 2017 for ACT, averaging scores from four sections, between 1 and 36|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
a = list(satdata2017['state']) 
b = list(actdata2017['state'])

c = [ states for states in b if states not in a]
c
# Out:
# ['National']

# %%
actdata2017
# Out:
#                    state  act2017_participation  act2017_english  \
# 0               National                   60.0             20.3
# 1                Alabama                  100.0             18.9
# 2                 Alaska                   65.0             18.7
# 3                Arizona                   62.0             18.6
# 4               Arkansas                  100.0             18.9
# 5             California                   31.0             22.5
# 6               Colorado                  100.0             20.1
# 7            Connecticut                   31.0             25.5
# 8               Delaware                   18.0             24.1
# 9   District of Columbia                   32.0             24.4
# 10               Florida                   73.0             19.0
# 11               Georgia                   55.0             21.0
# 12                Hawaii                   90.0             17.8
# ...

# %%
# removal of National in ACT 2017 data
actdata2017 = actdata2017.drop(actdata2017.index[0])

# %%
actdata2017.reset_index(inplace = True, drop = True)

# %%
actdata2017
# Out:
#                    state  act2017_participation  act2017_english  \
# 0                Alabama                  100.0             18.9
# 1                 Alaska                   65.0             18.7
# 2                Arizona                   62.0             18.6
# 3               Arkansas                  100.0             18.9
# 4             California                   31.0             22.5
# 5               Colorado                  100.0             20.1
# 6            Connecticut                   31.0             25.5
# 7               Delaware                   18.0             24.1
# 8   District of Columbia                   32.0             24.4
# 9                Florida                   73.0             19.0
# 10               Georgia                   55.0             21.0
# 11                Hawaii                   90.0             17.8
# 12                 Idaho                   38.0             21.9
# ...

# %%
satdata2017
# Out:
#                    state  sat2017_participation  sat2017_ebrw  sat2017_math  \
# 0                Alabama                    5.0         593.0         572.0
# 1                 Alaska                   38.0         547.0         533.0
# 2                Arizona                   30.0         563.0         553.0
# 3               Arkansas                    3.0         614.0         594.0
# 4             California                   53.0         531.0         524.0
# 5               Colorado                   11.0         606.0         595.0
# 6            Connecticut                  100.0         530.0         512.0
# 7               Delaware                  100.0         503.0         492.0
# 8   District of Columbia                  100.0         482.0         468.0
# 9                Florida                   83.0         520.0         497.0
# 10               Georgia                   61.0         535.0         515.0
# ...

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
#Code:
sat_act_2017 = pd.merge(satdata2017,actdata2017, on='state')

# %%
sat_act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   state                  51 non-null     object
#  1   sat2017_participation  51 non-null     float64
#  2   sat2017_ebrw           51 non-null     float64
#  3   sat2017_math           51 non-null     float64
#  4   sat2017_total          51 non-null     float64
#  5   act2017_participation  51 non-null     float64
#  6   act2017_english        51 non-null     float64
#  7   act2017_math           51 non-null     float64
#  8   act2017_reading        51 non-null     float64
#  9   act2017_science        51 non-null     float64
#  10  act2017_composite      51 non-null     float64
# dtypes: float64(10), object(1)
# memory usage: 4.8+ KB

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#code
sat_act_2017.to_csv('../data/combined_2017.csv')

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
satdata2018 = pd.read_csv('../data/sat_2018.csv')
actdata2018 = pd.read_csv('../data/act_2018_updated.csv')

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %% [markdown]
# # Rename to lower case and put _ in column titles
# # convert proper data types
# # export to new csv

# %%
actdata2018.head(2)
# Out:
#      State  Percentage of Students Tested  Average Composite Score  \
# 0  Alabama                            100                     19.1
# 1   Alaska                             33                     20.8
#
#    Average English Score  Average Math Score  Average Reading Score  \
# 0                   18.9                18.3                   19.6
# 1                   19.8                20.6                   21.6
#
#    Average Science Score
# 0                   19.0
# 1                   20.7

# %% [markdown]
# Ensure act data 2018 columns similiar to act 2017 starting columns
#
# State	Participation	English	Math	Reading	Science	Composite

# %%
act2018cols = [ 'State', 'Participation','English','Math','Reading','Science','Composite']
actdata2018.columns = act2018cols
actdata2018
# Out:
#                    State  Participation  English  Math  Reading  Science  \
# 0                Alabama            100     19.1  18.9     18.3     19.6
# 1                 Alaska             33     20.8  19.8     20.6     21.6
# 2                Arizona             66     19.2  18.2     19.4     19.5
# 3               Arkansas            100     19.4  19.1     18.9     19.7
# 4             California             27     22.7  22.5     22.5     23.0
# 5               Colorado             30     23.9  23.9     23.2     24.4
# 6            Connecticut             26     25.6  26.0     24.8     26.1
# 7               Delaware             17     23.2  23.7     23.1     24.5
# 8   District of Columbia             32     23.6  23.7     22.7     24.4
# 9                Florida             66     19.9  19.2     19.3     21.1
# 10               Georgia             53     21.4  20.9     20.7     21.2
# 11                Hawaii             89     18.9  18.2     19.0     19.1
# ...

# %%
satdata2018.head(2)
# Out:
#      State Participation  Evidence-Based Reading and Writing  Math  Total
# 0  Alabama            6%                                 595   571   1166
# 1   Alaska           43%                                 562   544   1106

# %% [markdown]
# # sat 2018 and act 2018, if not float , change to float

# %%
for columns in satdata2018.columns[2:]:
    if satdata2018[columns].dtypes != 'float':
        satdata2018[columns] = satdata2018[columns].astype('float')

# %%
for columns in actdata2018.columns[2:]:
    if actdata2018[columns].dtypes != 'float':
        actdata2018[columns] = actdata2018[columns].astype('float')

# %% [markdown]
# # sat 2018 and act 2018, remove % , and change to float for Participation

# %%
actdata2018['Participation'] = actdata2018['Participation'].map(partici_to_number)

# %%
satdata2018['Participation'] = satdata2018['Participation'].map(partici_to_number)

# %% [markdown]
# # Update columns with function, that changes to all lower, and add prefix

# %%
update_cols(satdata2018, 'sat2018_')
# Out:
#                    state  sat2018_participation  sat2018_ebrw  sat2018_math  \
# 0                Alabama                    6.0         595.0         571.0
# 1                 Alaska                   43.0         562.0         544.0
# 2                Arizona                   29.0         577.0         572.0
# 3               Arkansas                    5.0         592.0         576.0
# 4             California                   60.0         540.0         536.0
# 5               Colorado                  100.0         519.0         506.0
# 6            Connecticut                  100.0         535.0         519.0
# 7               Delaware                  100.0         505.0         492.0
# 8   District of Columbia                   92.0         497.0         480.0
# 9                Florida                   56.0         550.0         549.0
# 10               Georgia                   70.0         542.0         522.0
# ...

# %%
update_cols(actdata2018, 'act2018_')
# Out:
#                    state  act2018_participation  act2018_english  \
# 0                Alabama                  100.0             19.1
# 1                 Alaska                   33.0             20.8
# 2                Arizona                   66.0             19.2
# 3               Arkansas                  100.0             19.4
# 4             California                   27.0             22.7
# 5               Colorado                   30.0             23.9
# 6            Connecticut                   26.0             25.6
# 7               Delaware                   17.0             23.2
# 8   District of Columbia                   32.0             23.6
# 9                Florida                   66.0             19.9
# 10               Georgia                   53.0             21.4
# 11                Hawaii                   89.0             18.9
# 12                 Idaho                   36.0             22.3
# ...

# %%
# Merging of SAT 2018 to existing [ SAT 2017 , ACT 2017 ]
sat_act_2017_sat2018 = pd.merge(sat_act_2017,satdata2018, on='state')

# %%
# Merging of ACT 2018 to existing [ SAT 2017 , ACT 2017, SAT 2018 ]
sat_act_2017_2018 = pd.merge(sat_act_2017_sat2018,actdata2018, on='state')

# %%
# Exporting of CSV 
# SAT 2017 <> SAT 2018 <> ACT 2017 <> ACT 2018

sat_act_2017_2018.to_csv('../data/final.csv')

# %%
sat_act_2017_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   state                  51 non-null     object
#  1   sat2017_participation  51 non-null     float64
#  2   sat2017_ebrw           51 non-null     float64
#  3   sat2017_math           51 non-null     float64
#  4   sat2017_total          51 non-null     float64
#  5   act2017_participation  51 non-null     float64
#  6   act2017_english        51 non-null     float64
#  7   act2017_math           51 non-null     float64
#  8   act2017_reading        51 non-null     float64
#  9   act2017_science        51 non-null     float64
#  10  act2017_composite      51 non-null     float64
#  11  sat2018_participation  51 non-null     float64
#  12  sat2018_ebrw           51 non-null     float64
#  13  sat2018_math           51 non-null     float64
# ...

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:
sat_act_2017_2018.describe().T
# Out:
#                        count         mean        std    min      25%     50%  \
# sat2017_participation   51.0    39.803922  35.276632    2.0     4.00    38.0
# sat2017_ebrw            51.0   569.117647  45.666901  482.0   533.50   559.0
# sat2017_math            51.0   556.882353  47.121395  468.0   523.50   548.0
# sat2017_total           51.0  1126.098039  92.494812  950.0  1055.50  1107.0
# act2017_participation   51.0    65.254902  32.140842    8.0    31.00    69.0
# act2017_english         51.0    20.931373   2.353677   16.3    19.00    20.7
# act2017_math            51.0    21.182353   1.981989   18.0    19.40    20.9
# act2017_reading         51.0    22.013725   2.067271   18.1    20.45    21.8
# act2017_science         51.0    21.450980   1.739353   18.2    19.95    21.3
# act2017_composite       51.0    21.519608   2.020695   17.8    19.80    21.4
# sat2018_participation   51.0    45.745098  37.314256    2.0     4.50    52.0
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
#code
def std_dev_calc(column_values):
    
    n = len(column_values)
    u = column_values.mean()     
    sum_series_xi_minus_u = 0
    
    for x in column_values:
        
        square_xi_minus_u = np.square(x-u)
        sum_series_xi_minus_u += square_xi_minus_u
        
    
    std_dev = np.sqrt( (1/n) * sum_series_xi_minus_u )
    
    return std_dev

# %%
std_dev_calc(sat_act_2017_2018['sat2017_math'])
# Out:
# 46.65713364485503

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
#Code:
xd = {i:round(std_dev_calc(sat_act_2017_2018[i]),2) for i in sat_act_2017_2018.columns if i !='state'}

# %%
xd
# Out:
# {'sat2017_participation': 34.93,
#  'sat2017_ebrw': 45.22,
#  'sat2017_math': 46.66,
#  'sat2017_total': 91.58,
#  'act2017_participation': 31.82,
#  'act2017_english': 2.33,
#  'act2017_math': 1.96,
#  'act2017_reading': 2.05,
#  'act2017_science': 1.72,
#  'act2017_composite': 2.0,
#  'sat2018_participation': 36.95,
#  'sat2018_ebrw': 47.03,
#  'sat2018_math': 47.3,
#  'sat2018_total': 93.23,
#  'act2018_participation': 33.75,
#  'act2018_english': 2.09,
#  'act2018_math': 2.42,
#  'act2018_reading': 2.02,
#  'act2018_science': 2.15,
#  'act2018_composite': 1.85}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer
#
#
# The manually calculated standard deviations do not match up to the output from Pandas describe. However, it matches up to NumPy's std method. This discrepancy occurs because Pandas uses $N-1$ in its denominator instead of $N$ like NumPy. This is known as Bessel's correction, where $N-1$ instead of $N$ is used in the denominator of the standard deviation formula.

# %%
np.std(sat_act_2017_2018)
# Out:
# sat2017_participation    34.929071
# sat2017_ebrw             45.216970
# sat2017_math             46.657134
# sat2017_total            91.583511
# act2017_participation    31.824176
# act2017_english           2.330488
# act2017_math              1.962462
# act2017_reading           2.046903
# act2017_science           1.722216
# act2017_composite         2.000786
# sat2018_participation    36.946619
# sat2018_ebrw             47.034610
# sat2018_math             47.301946
# sat2018_total            93.227424
# act2018_participation    33.745195
# act2018_english           2.085526
# act2018_math              2.422254
# act2018_reading           2.015707
# act2018_science           2.145892
# act2018_composite         1.851689
# dtype: float64

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# # SAT 2017 Participation

# %%
sat_act_2017_2018[['state','sat2017_participation']].sort_values('sat2017_participation',ascending = False).head()
# Out:
#                    state  sat2017_participation
# 8   District of Columbia                  100.0
# 22              Michigan                  100.0
# 6            Connecticut                  100.0
# 7               Delaware                  100.0
# 29         New Hampshire                   96.0

# %%
sat_act_2017_2018[['state','sat2017_participation']].sort_values('sat2017_participation',ascending = True).head()
# Out:
#            state  sat2017_participation
# 34  North Dakota                    2.0
# 24   Mississippi                    2.0
# 15          Iowa                    2.0
# 25      Missouri                    3.0
# 44          Utah                    3.0

# %% [markdown]
# # SAT 2017 participation rates findings
# - North Dakota, Mississippi, and Iowa have the lowest participation rates at 2%.
# - The District of Columbia, Michigan, Connecticut, and Delaware have the highest participation rates at 100%.

# %% [markdown]
# # SAT 2018 Participation

# %%
sat_act_2017_2018[['state','sat2018_participation']].sort_values('sat2018_participation',ascending = False).head(7)
# Out:
#           state  sat2018_participation
# 5      Colorado                  100.0
# 6   Connecticut                  100.0
# 7      Delaware                  100.0
# 22     Michigan                  100.0
# 12        Idaho                  100.0
# 19        Maine                   99.0
# 13     Illinois                   99.0

# %%
sat_act_2017_2018[['state','sat2018_participation']].sort_values('sat2018_participation',ascending = True).head()
# Out:
#            state  sat2018_participation
# 34  North Dakota                    2.0
# 50       Wyoming                    3.0
# 41  South Dakota                    3.0
# 27      Nebraska                    3.0
# 49     Wisconsin                    3.0

# %% [markdown]
# # SAT 2018 participation rates findings
# - North Dakota has the lowest participation rates at 2%.
# - Colorado, Connecticut, Delaware, Michigan, and Idaho have the highest participation rates at 100%.

# %% [markdown]
# # ACT 2017 participation rates

# %%
sat_act_2017_2018[['state','act2017_participation']].sort_values('act2017_participation',ascending = True).head()
# Out:
#             state  act2017_participation
# 19          Maine                    8.0
# 29  New Hampshire                   18.0
# 7        Delaware                   18.0
# 39   Rhode Island                   21.0
# 38   Pennsylvania                   23.0

# %%
sat_act_2017_2018[['state','act2017_participation']].sort_values('act2017_participation',ascending = False).head(20)
# Out:
#              state  act2017_participation
# 0          Alabama                  100.0
# 17        Kentucky                  100.0
# 49       Wisconsin                  100.0
# 44            Utah                  100.0
# 42       Tennessee                  100.0
# 40  South Carolina                  100.0
# 36        Oklahoma                  100.0
# 33  North Carolina                  100.0
# 28          Nevada                  100.0
# 26         Montana                  100.0
# 24     Mississippi                  100.0
# 23       Minnesota                  100.0
# 18       Louisiana                  100.0
# 25        Missouri                  100.0
# 50         Wyoming                  100.0
# 5         Colorado                  100.0
# 3         Arkansas                  100.0
# 34    North Dakota                   98.0
# 13        Illinois                   93.0
# 11          Hawaii                   90.0

# %% [markdown]
# # ACT 2017 participation rates findings
# - Maine has the lowest participation rate at 8%.
# - ACT's lowest participation rates are not as low as SAT's lowest participation rates.
# - Alabama, Kentucky, Wisconsin, Utah, Tennessee, South Carolina, Oklahoma, North Carolina, - Nevada,Montana, Mississippi, Minnesota, Louisiana, Missouri, Wyoming, Colorado, and Arkansas
# - have the highest participation rates at 100%.
# - ACT has a lot more states with a 100% participation rate compared to the SAT.

# %% [markdown]
# # ACT 2018 Participation

# %%
sat_act_2017_2018[['state','act2018_participation']].sort_values('act2018_participation',ascending = False).head(20)
# Out:
#              state  act2018_participation
# 0          Alabama                  100.0
# 17        Kentucky                  100.0
# 49       Wisconsin                  100.0
# 44            Utah                  100.0
# 42       Tennessee                  100.0
# 40  South Carolina                  100.0
# 36        Oklahoma                  100.0
# 35            Ohio                  100.0
# 33  North Carolina                  100.0
# 28          Nevada                  100.0
# 27        Nebraska                  100.0
# 26         Montana                  100.0
# 24     Mississippi                  100.0
# 18       Louisiana                  100.0
# 25        Missouri                  100.0
# 50         Wyoming                  100.0
# 3         Arkansas                  100.0
# 23       Minnesota                   99.0
# 34    North Dakota                   98.0
# 11          Hawaii                   89.0

# %%
sat_act_2017_2018[['state','act2018_participation']].sort_values('act2018_participation',ascending = True).head()
# Out:
#             state  act2018_participation
# 19          Maine                    7.0
# 39   Rhode Island                   15.0
# 29  New Hampshire                   16.0
# 7        Delaware                   17.0
# 38   Pennsylvania                   20.0

# %% [markdown]
# # ACT 2018 participation rates findings
# - Maine has the lowest participation rate at 7%.
# - Alabama, Kentucky, Wisconsin, Utah, Tennessee, South Carolina, Oklahoma, Ohio, North Carolina, - Nevada, Nebraska, Montana, Mississippi, Louisiana, Missouri, Wyoming, and Arkansas have the highest participation rates at 100%.

# %% [markdown]
# # SAT 2017 Total

# %%
sat_act_2017_2018[['state','sat2017_total']].sort_values('sat2017_total',ascending = True).head()
# Out:
#                    state  sat2017_total
# 8   District of Columbia          950.0
# 7               Delaware          996.0
# 12                 Idaho         1005.0
# 22              Michigan         1005.0
# 19                 Maine         1012.0

# %%
sat_act_2017_2018[['state','sat2017_total']].sort_values('sat2017_total',ascending = False).head()
# Out:
#         state  sat2017_total
# 23  Minnesota         1295.0
# 49  Wisconsin         1291.0
# 15       Iowa         1275.0
# 25   Missouri         1271.0
# 16     Kansas         1260.0

# %% [markdown]
# # SAT 2017 Total findings
# - Lowest = District of Columbia
# - Highest = Minnesota

# %% [markdown]
# # SAT 2018 Total

# %%
sat_act_2017_2018[['state','sat2018_total']].sort_values('sat2018_total',ascending = False).head()
# Out:
#            state  sat2018_total
# 23     Minnesota         1298.0
# 49     Wisconsin         1294.0
# 34  North Dakota         1283.0
# 15          Iowa         1265.0
# 16        Kansas         1265.0

# %%
sat_act_2017_2018[['state','sat2018_total']].sort_values('sat2018_total',ascending = True).head()
# Out:
#                    state  sat2018_total
# 8   District of Columbia          977.0
# 7               Delaware          998.0
# 48         West Virginia          999.0
# 12                 Idaho         1001.0
# 44                  Utah         1010.0

# %% [markdown]
# # SAT 2018 Total findings
# - Lowest = District of Cloumiba
# - Highest = Minnesota

# %% [markdown]
# # ACT 2017 Composite

# %%
sat_act_2017_2018[['state','act2017_composite']].sort_values('act2017_composite',ascending = True).head()
# Out:
#              state  act2017_composite
# 28          Nevada               17.8
# 24     Mississippi               18.6
# 40  South Carolina               18.7
# 11          Hawaii               19.0
# 33  North Carolina               19.1

# %%
sat_act_2017_2018[['state','act2017_composite']].sort_values('act2017_composite',ascending = False).head()
# Out:
#                    state  act2017_composite
# 29         New Hampshire               25.5
# 21         Massachusetts               25.4
# 6            Connecticut               25.2
# 19                 Maine               24.3
# 8   District of Columbia               24.2

# %% [markdown]
# # ACT 2017 Composite findings
# - lowest = Nevada
# - highest = New Hampshire

# %% [markdown]
# # ACT 2018 Composite

# %%
sat_act_2017_2018[['state','act2018_composite']].sort_values('act2018_composite',ascending = False).head()
# Out:
#             state  act2018_composite
# 6     Connecticut               24.9
# 21  Massachusetts               24.7
# 29  New Hampshire               24.4
# 32       New York               24.2
# 22       Michigan               23.9

# %%
sat_act_2017_2018[['state','act2018_composite']].sort_values('act2018_composite',ascending = True).head()
# Out:
#              state  act2018_composite
# 28          Nevada               17.9
# 40  South Carolina               18.5
# 24     Mississippi               18.6
# 0          Alabama               19.0
# 11          Hawaii               19.0

# %% [markdown]
# # ACT 2018 Composite findings
# - lowest = Nevada
# - highest = Connecticut

# %% [markdown]
# # Do any states with 100% participation on a given test have a rate change year-to-year?

# %%
mask = (sat_act_2017_2018['act2017_participation'] == 100) &\
(sat_act_2017_2018['act2018_participation'] < 100)

sat_act_2017_2018[mask][['state','act2017_participation', 'act2018_participation']]
# Out:
#         state  act2017_participation  act2018_participation
# 5    Colorado                  100.0                   30.0
# 23  Minnesota                  100.0                   99.0

# %%
sat_act_2017_2018[mask][['state','act2017_participation', 'act2018_participation','sat2017_participation','sat2018_participation']]
# Out:
#         state  act2017_participation  act2018_participation  \
# 5    Colorado                  100.0                   30.0
# 23  Minnesota                  100.0                   99.0
#
#     sat2017_participation  sat2018_participation
# 5                    11.0                  100.0
# 23                    3.0                    4.0

# %% [markdown]
# # ACT 2017 vs ACT 2018
# # Colorado ! The huge jump from ACT to SAT
# It seems that colorado and minnesota had 100% participation in 2017 , and then in 2018 Colardo had a big drop to 30%

# %%
mask = (sat_act_2017_2018['sat2017_participation'] == 100) &\
(sat_act_2017_2018['sat2018_participation'] < 100)

sat_act_2017_2018[mask][['state','act2017_participation', 'act2018_participation','sat2017_participation','sat2018_participation']]
# Out:
#                   state  act2017_participation  act2018_participation  \
# 8  District of Columbia                   32.0                   32.0
#
#    sat2017_participation  sat2018_participation
# 8                  100.0                   92.0

# %% [markdown]
# # SAT 2017 vs SAT 2018
# # District of Columbia ! Maintaing such high participation rate for SAT
# It seems that SAT 2017 and SAT 2018 was the preferred examination to be taken for District of Columbia for both years.
#
# Why is that so ??

# %% [markdown]
# # Any states maintiang more than 50% participation rate in both years and both tests ?

# %%
mask = (sat_act_2017_2018['sat2017_participation'] >=50) &\
(sat_act_2017_2018['sat2018_participation'] >= 50) &\
(sat_act_2017_2018['act2018_participation'] >= 50) & \
(sat_act_2017_2018['act2017_participation'] >= 50) 

sat_act_2017_2018[mask][['state','act2017_participation', 'act2018_participation','sat2017_participation','sat2018_participation']]
# Out:
#              state  act2017_participation  act2018_participation  \
# 9          Florida                   73.0                   66.0
# 10         Georgia                   55.0                   53.0
# 11          Hawaii                   90.0                   89.0
# 40  South Carolina                  100.0                  100.0
#
#     sat2017_participation  sat2018_participation
# 9                    83.0                   56.0
# 10                   61.0                   70.0
# 11                   55.0                   56.0
# 40                   50.0                   55.0

# %% [markdown]
# # How are these states maintaing such high participation for both exams ?
# - Florida
# - Georgia
# - Hawaii
# - South Carolina

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
custom_mask = np.zeros_like(sat_act_2017_2018.corr()) # creating a zero matrix of the same size as the correlation matrix
upper_triangle_index = np.triu_indices_from(custom_mask) # Generate indices corresponding to the upper triangle of the matrix
custom_mask[upper_triangle_index] = True # set the upper triangle indices of the matrix to 1

fig, ax = plt.subplots(figsize=(15,15))
sat_act_2017_2018_correlations = sat_act_2017_2018.corr();
sns.heatmap(sat_act_2017_2018_correlations, annot=True,vmin=-1,cmap='coolwarm',mask=custom_mask);
plt.title('Correlation btn each test results and pariticpation rate of 2017 and 2018');

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles):
    nrows = int(np.ceil(len(list_of_columns)/2)) 
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(10,10)) 
    ax = ax.ravel()                              # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        if 'act' in column:
            color = 'steelblue'
        else:
            color = 'darkcyan'
        ax[i].hist(dataframe[column], color=color)
        ax[i].set_title(list_of_titles[i], fontsize=16)
        ax[i].axvline(x=dataframe[column].median(), color='b', label='median')
        ax[i].axvline(x=dataframe[column].mean(), color='r', label='mean')
        ax[i].legend(loc=0, frameon=False)
    fig.tight_layout(pad=3.0)

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
# Code

participation_cols = ['act2017_participation', 'act2018_participation', 'sat2017_participation', 'sat2018_participation']
math_cols = ['act2017_math', 'act2018_math', 'sat2017_math', 'sat2018_math']
reading_cols = ['act2017_reading', 'act2018_reading', 'sat2017_ebrw', 'sat2018_ebrw']

participation_titles = ['ACT 2017 Participation', 'ACT 2018 Participation', 
                        'SAT 2017 Participation', 'SAT 2018 Participation']
math_titles = ['ACT 2017 Math Scores', 'ACT 2018 Math Scores', 'SAT 2017 Math Scores', 'SAT 2018 Math Scores']
reading_titles = ['ACT 2017 Reading Scores', 'ACT 2018 Reading Scores', 
                  'SAT 2017 Reading and Writing Scores', 'SAT 2018 Reading and Writing Scores']

# %% [markdown]
# # Participation Rate Analysis
#
# ### ACT
# ##### When comparing the ACT 2017 to 2018, the histogram shape are similar, the mean and median is ~60& and ~70% respectively,  this means ACT year on year change is quite minimal
#
# ### SAT
# ##### The same is noted for the year on year change for SAT 2017 to 2018
#
# ##### the noteable observations here would be, SAT and ACT can be seen as a strong competitor as it when ACT 2017 participation is high, SAT 2017 participation is low in about the same magnitude ~20 counts.

# %%
subplot_histograms(sat_act_2017_2018, participation_cols, participation_titles)

# %% [markdown]
# # Math scoring Analysis
#
# ### ACT
# ##### Year on Year comparison, the mean and median are relatively close, ~ 20 points
#
# ### SAT
# ##### Year on Year comparison, the mean and median are relatively close, ~ 555 points
#
# ##### the noteable observations here would be ACT where in 2017 students that score 21.5 to23.5 , seems to have been spread out to the range of 23.5 to 24.5 range

# %%
subplot_histograms(sat_act_2017_2018, math_cols, math_titles)

# %% [markdown]
# # Reading score Analysis
#
# ### ACT
# ##### Year on Year comparison, the mean and median are relatively close, ~ 20 points
#
# ### SAT
# ##### Year on Year comparison, the mean and median are relatively close, ~ 555 points

# %%
subplot_histograms(sat_act_2017_2018, reading_cols, reading_titles)

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
def subplot_scatter(dataframe, list_of_x, list_of_y, list_of_titles):
    nrows = int(np.ceil(len(list_of_x)/5)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2,sharex=False,sharey=False,figsize=(15,nrows*6)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate

   # for j in list_of2:# Gives us an index value to get into all our lists
    for i, column in enumerate(list_of_x):
            sns.regplot(dataframe[column],dataframe[list_of_y[i]],ax=ax[i]) # feel free to add more settings 
    for x,titles in enumerate(list_of_titles):
            ax[x].title.set_text(titles)

# %%
scattercols_x1 = ['act2017_math', 'act2017_reading']
scattercols_y1 =[ 'sat2017_math', 'sat2017_ebrw',] 
scattercols_titles = ['Math 2017 / ACT VS SAT ',' Reading 2017 - ACT VS SAT']

# %% [markdown]
# ## Comparing between, SAT & ACT year 2017 , comparing against subjects
#
# ### Left is math
# ### Right is english
#
# ### Both shows a download sloping line, i.e. if u do well in math for SAT , u tend to fare poorer in math ACT, this clearly shows that what students learn in school, the syllabus is more incline to SAT, where students cna score better.

# %%
# Code
subplot_scatter (sat_act_2017_2018 , scattercols_x1 , scattercols_y1, scattercols_titles)

# %%
scattercols_x2 = [ 'act2017_composite']
scattercols_y2 = ['sat2017_total']
scattercols_titles2 = ['SAT vs. ACT total/composite scores for 2017']

# %%
subplot_scatter (sat_act_2017_2018 , scattercols_x2 , scattercols_y2, scattercols_titles2)

# %%
scattercols_x3 = ['act2017_composite','sat2018_total']
scattercols_y3 = [ 'act2018_composite','sat2017_total']
scattercols_titles3 = ['Composite scores for ACT 2017 vs. 2018' ,'Total scores for SAT 2017 vs. 2018']

# %% [markdown]
# ### There is generally a upward sloping trend between the 2017 and 2018 scores for both the SAT and ACT composite and total, which means that most states were able to maintain their performance in the tests respectively.

# %%
subplot_scatter (sat_act_2017_2018 , scattercols_x3 , scattercols_y3, scattercols_titles3)

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
def boxplt(dataframe, x_label, y_label, title):
    fig, ax = plt.subplots(figsize=(6,5))
       
    ax = sns.boxplot(data=dataframe, orient='h', palette="Blues")
    
    ax.set_title(title, fontsize=16)                 
    ax.set_xlabel(x_label, fontsize=13)
    ax.set_ylabel(y_label, fontsize=13)

# %% [markdown]
# ## SAT
#
# - 2017 the IQR is ~0 to ~60 participation rate, the median is ~40
# - 2018 the IQR is ~0% to ~75 participation rate, the median is ~50
#
# ## Increase in IQR!
# from 2017 to 2018, the IQR has increased to ~75 , this means SAT impelemented some new mandate or marketing technique, that actually helped to grew its participation rate quite significantly, and requries background research on what they have done right to achieve this result!

# %%
boxplt(sat_act_2017_2018[['sat2017_participation', 'sat2018_participation', 'act2017_participation', 'act2018_participation']], 
           'Participation rate', '', 'ACT and SAT participation in 2017 and 2018')

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# ## Comparing ACT Composite Year on Year
#
# ### - There were not much changes in the results as they are relatively similar

# %%
boxplt(sat_act_2017_2018[['act2017_composite', 'act2018_composite']], 
           'ACT composite score', '', 'ACT composite score in 2017 and 2018')

# %% [markdown]
# # After analysing the boxplot  of SAT vs ACT 2017 , 2018
# # It is worthy to look further into the relationship through a scatterplot and line of best fit to see if there is any relationship

# %% [markdown]
# ## When we look at the participation rate, against the 2 examination, each year, it clearly shows that there is an inverse relationship that we should understand further
#
# ## Our end goal is to assist the College Board on driving its SAT participation rate up!

# %%
scattercols_x4 = ['act2017_participation', 'act2018_participation']
scattercols_y4 =[ 'sat2017_participation', 'sat2018_participation',] 
scattercols_titles4 = ['2017 - SAT VS ACT ',' 2018 - ACT VS SAT']

# %%
subplot_scatter (sat_act_2017_2018 , scattercols_x4 , scattercols_y4, scattercols_titles4)

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# ## Participation rates
# ### SAT
# SAT mean participation rate grew from 39.80 to 45.74
# For both years, the minimum is 2 and the maximum is 100, with a standard deviation of 35. This means that there is a huge variation in SAT participation rates across the U.S. states.
# ### ACT
# ACT mean participation rate drop from 65.25 to 61.65
# Participation rates range from 7 to 100, with a standard deviation of 32. Similar to the SAT, there is a huge variation in ACT participation rates across the U.S. states.

# %%
j1 = sat_act_2017_2018[['sat2017_participation','act2017_participation',
                        'sat2018_participation','act2018_participation']]
j1.describe().T
# Out:
#                        count       mean        std  min   25%   50%    75%  \
# sat2017_participation   51.0  39.803922  35.276632  2.0   4.0  38.0   66.0
# act2017_participation   51.0  65.254902  32.140842  8.0  31.0  69.0  100.0
# sat2018_participation   51.0  45.745098  37.314256  2.0   4.5  52.0   77.5
# act2018_participation   51.0  61.647059  34.080976  7.0  28.5  66.0  100.0
#
#                          max
# sat2017_participation  100.0
# act2017_participation  100.0
# sat2018_participation  100.0
# act2018_participation  100.0

# %% [markdown]
# Answers:

# %% [markdown]
# #### Distributions in the data
#
# In this dataset, each data represents a sample from a population.
# For example, for ACT math test:
# - Population: the test results of all the students who take this test, nation-wide.
# - Population mean: is the national average of ACT math test (total scores/total no. of test takers)
# - Sample: the state means of ACT math test. We have 51 samples (51 states)
#
# ***According to CLT, we generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?***

# %% [markdown]
# Answer:
#
#  <font size = 3 color = "blue"> *Defining the terms in the context of this dataset:*
# - Population - total nationwide high school seniors that took SAT and/or ACT in a particular year
# - Number of samples - 51 samples (Total number of states)
# - Sample size - varies by number of participants in each state, and therefore each sample's mean is calculated against different totals.
#
# From the data visualisations done so far, none of the data variables follow a normal distribution. <br>
# This is because of a few reasons:
# - The sampling done from the population is not random, as it is influenced by outside factors such as state legislation, contracts with schools etc.
# - The size of the sample is not constant. Each state has varying participation rates which are also derived from varying number of total high school seniors taking SAT and/or ACT. Therefore the variance in sample size is very high.
# - The number of samples (51) is too low.
#
# For the normality assumption to hold true:
# - The sampling has to be random (i.e. no arbritary constraints imposed on the sampling process such as legislation)
# - The number of samples has to be big enough.
# - The sample size ideally should be constant. </font>

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer:
#
# - Participation rates
#
# The participation rates for the SAT and ACT are not normally distributed. Instead, there is a concentration of states at either end of the range of values as described previously. This is because SAT and ACT participation are not independent of each other, and they are also influenced by state regulations, e.g. whether the states have existing contracts with ACT or College Board, or whether the state has mandated a different test for graduating high school students.
#
# - Math and Reading scores
#
# Compared to Participation rates, the histograms for Math and Reading scores for both the SAT and ACT more closely resemble a normal distribution. However, we cannot conclude that the scores are normally distributed because the histograms are left/right-skewed, and mostly have more than one peak. For histograms with multiple peaks, there is usually one (or more) in the 1st/2nd quartile, and one (or more) in the 3rd/4th quartile of the range of scores.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer:
#
# - No, we cannot conduct statistical inference using this data.
#
# - This is because the samples in the dataset are not randomly chosen. They represent information specific to each of the 51 states, which would have varying circumstances and demographic data.
# - ACT and SAT participation rates are correlated, , the Central Limit Theorem does not hold and we cannot use these samples to make statistical inferences about the entire population's ACT and SAT participation rates.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores  - can we say students with higher SAT math score is better than those with lower ACT math score, or vice versa?
#
# Why or why not?

# %% [markdown]
# Answer:
# - It is not appropriate. The SAT and ACT math scores have different scales (200-800 for SAT and 1-36 for ACT). Also, there may likely be differences in the format and the topics tested in the SAT and ACT math test, so we cannot compare the two tests fairly.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# ### Illinois
#
# SAT participation shot up from 9% in 2017 to 99% in 2018. ACT participation plunged to 43% in 2018 from 93% in 2017.
# Illinois transitioned from the ACT to SAT after awarding the College Board a contract to administer the SAT to all its public high school juniors.
# The SAT test became state-funded and free to take for all high school juniors.
#
# ### Colorado
# Similar to Illinois, the College Board won a contract to administer the SAT to all high school juniors in Colorado.
# The SAT is also state-funded in Colorado and free for students to take.
# As a result, participation rate for the SAT shot up from 11% in 2017 to 100% in 2018.
# Correspondingly, the ACT participation rate fell from 100% to 30%.
#
#
# ### Ohio
# Ohio is my recommended state to target, as you will see in the next section, so let's take a deeper look at its 2017 and 2018 ACT and SAT data.
#
# From 2017 to 2018, Ohio increased both its ACT and SAT participation. However, the increase was larger for the ACT, i.e. from 75% to 100%, whereas for SAT it was from 12% to 18%.
#
# The increased in participation in the ACT and SAT came about after the state made it a requirement for all school districts to give all graduating students the ACT or SAT, regardless of whether they are going to college.
#
# It is likely that the ACT saw a greater increase in participation rate because it was already the more widely taken test in Ohio.
#
# It is also important to note that the fees for the SAT are higher than the ACT, which would give Ohio schools less incentive to offer the SAT to students.
#
# State Funding
# https://www.chicagotribune.com/news/breaking/ct-met-illinois-act-test-scores-20181016-story.html
#
# Contract from ACT to SAT
# https://www.chicagotribune.com/news/breaking/ct-met-illinois-act-test-scores-20181016-story.html
# https://www.chicagotribune.com/news/ct-illinois-chooses-sat-met-20160211-story.html

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# - Inverse relationship between SAT vs. ACT participation rates
# - - SAT and ACT participation rates have an inverse relationship, as seen from the general downward sloping trend below. This is expected as the two tests are usually substitutes of one another, thus a higher participation in one test would see a lower participation in the other.
# There were more SAT than ACT test-takers in 2018, but ACT still enjoys greater popularity in more states.
# - Statefunding
# - - As part of high school accountability, the SAT was state-funded for students to take for free.
# Free testing significantly boosts participation rate.
# As seen, state-funding dramatically boosted SAT participation in Illinois and Colorado as students were more likely to take the free SAT than the paid ACT. The College Board would do well to target states that are already funding the ACT or other college admission tests and convince them to adopt (and fund) the SAT instead. This would allow the SAT to be taken by a wider group of students, e.g. students from lower-income families who would not have taken the SAT if it were not free and state-required.

# %% [markdown]
# Final recommendation: Target Ohio
# - Large population: Ohio is the 7th most populous state in the U.S., so there is a sizeable number of new test-takers that the College Board can acquire.
# - Relatively low current SAT participation rates: From 2017 to 2018, Ohio increased both its ACT and SAT participation after it became compulsory to take either test. However, the increase was larger for the ACT, i.e. from 75% to 100%, whereas for SAT it was from 12% to 18%. Thus, there is still considerable room for growth for the SAT.
# - High state debts: In 2017, Ohio had the 10th highest amount of state debt. If the College Board employs the same strategy of underbidding ACT, Inc. and make the cost of implementing the SAT lower compared to the ACT, they would increase their chances of persuading the Ohio Department of Education to adopt the SAT statewide.
# - Free to take the ACT or SAT: The ACT and SAT are already free for public school students to take. Thus, the main task left for College Board is to explain to the Department of Education why it would be more beneficial for students to take the SAT instead of the ACT.
